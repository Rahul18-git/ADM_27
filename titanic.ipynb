# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahul18-git/ADM_27/blob/main/titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from google.colab import files

# Upload a file manually
uploaded = files.upload()

data = pd.read_csv('Titanic (3).csv')
print("Original DataFrame with missing values:")
print(data.info())
print(data.isnull().sum())
if 'BMI' in data.columns:
    data['BMI'] = data['BMI'].fillna(data['BMI'].mean())

if 'Fare' in data.columns:
    data['Fare'] = data['Fare'].fillna(data['Fare'].median())

if 'Embarked' in data.columns:
    data['Embarked'] = data['Embarked'].fillna(data['Embarked'].mode()[0])

print("\nDataFrame after handling missing values:")
print(data.info())
print(data.isnull().sum())
# Out:
#      <input type="file" id="files-9a1806bb-1fd1-441e-9567-6b400ab42c10" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a1806bb-1fd1-441e-9567-6b400ab42c10">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
s = pd.Series([12,1,5,3,2])
print(s)

ds1 = pd.Series([2, 4, 6, 8, 10])
ds2 = pd.Series([1, 3, 5, 7, 9])
print("sum of series elements")
ds = ds1 + ds2
print(ds)

ds1 = pd.Series([2, 4, 6, 8, 10])
ds2 = pd.Series([1, 3, 5, 7, 9])
print("multiply of series elements")
ds = ds1 * ds2
print(ds)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 0    12
# 1     1
# 2     5
# 3     3
# 4     2
# dtype: int64
# sum of series elements
# 0     3
# 1     7
# 2    11
# 3    15
# 4    19
# dtype: int64
# multiply of series elements
# 0     2
# 1    12
# 2    30
# 3    56
# 4    90
# dtype: int64

# %%
import pandas as pd
from google.colab import files
my_path = '/content/banklist.csv'
data = pd.read_csv(my_path)
data.head()
# Out:
#   File "<ipython-input-10-0e9524d9ac3f>", line 4
#     data = pd.read_csv(Titanic\ \(3\).csv)
#                                ^
# SyntaxError: unexpected character after line continuation character
